# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/BL-Flickr-Images-Book.csv')

# %%
df.head()
# Out:
#    Identifier             Edition Statement      Place of Publication  \
# 0         206                           NaN                    London
# 1         216                           NaN  London; Virtue & Yorston
# 2         218                           NaN                    London
# 3         472                           NaN                    London
# 4         480  A new edition, revised, etc.                    London
#
#   Date of Publication              Publisher  \
# 0         1879 [1878]       S. Tinsley & Co.
# 1                1868           Virtue & Co.
# 2                1869  Bradbury, Evans & Co.
# 3                1851          James Darling
# 4                1857   Wertheim & Macintosh
#
#                                                Title     Author  \
# 0                  Walter Forbes. [A novel.] By A. A      A. A.
# 1  All for Greed. [A novel. The dedication signed...  A., A. A.
# 2  Love the Avenger. By the author of “All for Gr...  A., A. A.
# ...

# %%
#taking list of coloum head which has to be deleted
to_drop=['Edition Statement',
         'Corporate Author',
         'Corporate Contributors',
         'Corporate Contributors',
         'Former owner','Engraver',
         'Issuance type','Shelfmarks']

# %%
#drop function take the list of column that has to be deleted 
df.drop(to_drop,inplace=True,axis=1)

# %%
df.head()
# Out:
#    Identifier      Place of Publication Date of Publication  \
# 0         206                    London         1879 [1878]
# 1         216  London; Virtue & Yorston                1868
# 2         218                    London                1869
# 3         472                    London                1851
# 4         480                    London                1857
#
#                Publisher                                              Title  \
# 0       S. Tinsley & Co.                  Walter Forbes. [A novel.] By A. A
# 1           Virtue & Co.  All for Greed. [A novel. The dedication signed...
# 2  Bradbury, Evans & Co.  Love the Avenger. By the author of “All for Gr...
# 3          James Darling  Welsh Sketches, chiefly ecclesiastical, to the...
# 4   Wertheim & Macintosh  [The World in which I live, and my place in it...
#
#       Author                                  Contributors  \
# 0      A. A.                               FORBES, Walter.
# ...

# %%
dt=pd.read_csv('/content/BL-Flickr-Images-Book.csv')

# %%
dt.head()
# Out:
#    Identifier             Edition Statement      Place of Publication  \
# 0         206                           NaN                    London
# 1         216                           NaN  London; Virtue & Yorston
# 2         218                           NaN                    London
# 3         472                           NaN                    London
# 4         480  A new edition, revised, etc.                    London
#
#   Date of Publication              Publisher  \
# 0         1879 [1878]       S. Tinsley & Co.
# 1                1868           Virtue & Co.
# 2                1869  Bradbury, Evans & Co.
# 3                1851          James Darling
# 4                1857   Wertheim & Macintosh
#
#                                                Title     Author  \
# 0                  Walter Forbes. [A novel.] By A. A      A. A.
# 1  All for Greed. [A novel. The dedication signed...  A., A. A.
# 2  Love the Avenger. By the author of “All for Gr...  A., A. A.
# ...

# %%
dt.drop(to_drop,inplace=True,axis=1)

# %%
dt.head()
# Out:
#    Identifier      Place of Publication Date of Publication  \
# 0         206                    London         1879 [1878]
# 1         216  London; Virtue & Yorston                1868
# 2         218                    London                1869
# 3         472                    London                1851
# 4         480                    London                1857
#
#                Publisher                                              Title  \
# 0       S. Tinsley & Co.                  Walter Forbes. [A novel.] By A. A
# 1           Virtue & Co.  All for Greed. [A novel. The dedication signed...
# 2  Bradbury, Evans & Co.  Love the Avenger. By the author of “All for Gr...
# 3          James Darling  Welsh Sketches, chiefly ecclesiastical, to the...
# 4   Wertheim & Macintosh  [The World in which I live, and my place in it...
#
#       Author                                  Contributors  \
# 0      A. A.                               FORBES, Walter.
# ...

# %%
# deleting columns by pasing to coloumn paramater
#previous we delete the columns by passing list as lable to drop fuction
# in this we derictely pass to the function

# %%
cdt=pd.read_csv('/content/BL-Flickr-Images-Book.csv')

# %%
cdt.head()
# Out:
#    Identifier             Edition Statement      Place of Publication  \
# 0         206                           NaN                    London
# 1         216                           NaN  London; Virtue & Yorston
# 2         218                           NaN                    London
# 3         472                           NaN                    London
# 4         480  A new edition, revised, etc.                    London
#
#   Date of Publication              Publisher  \
# 0         1879 [1878]       S. Tinsley & Co.
# 1                1868           Virtue & Co.
# 2                1869  Bradbury, Evans & Co.
# 3                1851          James Darling
# 4                1857   Wertheim & Macintosh
#
#                                                Title     Author  \
# 0                  Walter Forbes. [A novel.] By A. A      A. A.
# 1  All for Greed. [A novel. The dedication signed...  A., A. A.
# 2  Love the Avenger. By the author of “All for Gr...  A., A. A.
# ...

# %%
cdt.drop(columns=to_drop,axis=1,inplace=True)

# %%
cdt.head()
# Out:
#    Identifier      Place of Publication Date of Publication  \
# 0         206                    London         1879 [1878]
# 1         216  London; Virtue & Yorston                1868
# 2         218                    London                1869
# 3         472                    London                1851
# 4         480                    London                1857
#
#                Publisher                                              Title  \
# 0       S. Tinsley & Co.                  Walter Forbes. [A novel.] By A. A
# 1           Virtue & Co.  All for Greed. [A novel. The dedication signed...
# 2  Bradbury, Evans & Co.  Love the Avenger. By the author of “All for Gr...
# 3          James Darling  Welsh Sketches, chiefly ecclesiastical, to the...
# 4   Wertheim & Macintosh  [The World in which I live, and my place in it...
#
#       Author                                  Contributors  \
# 0      A. A.                               FORBES, Walter.
# ...

# %%
cdt['Identifier'].is_unique
# Out:
# True

# %%
#Pandas indexextends the functionality of NumPy array to allow  for mpre versatile slicing and labeling
cdt= cdt.set_index('Identifier')

# %%
cdt.head()
# Out:
#                 Place of Publication Date of Publication  \
# Identifier
# 206                           London         1879 [1878]
# 216         London; Virtue & Yorston                1868
# 218                           London                1869
# 472                           London                1851
# 480                           London                1857
#
#                         Publisher  \
# Identifier
# 206              S. Tinsley & Co.
# 216                  Virtue & Co.
# 218         Bradbury, Evans & Co.
# 472                 James Darling
# 480          Wertheim & Macintosh
#
#                                                         Title     Author  \
# Identifier
# 206                         Walter Forbes. [A novel.] By A. A      A. A.
# 216         All for Greed. [A novel. The dedication signed...  A., A. A.
# 218         Love the Avenger. By the author of “All for Gr...  A., A. A.
# 472         Welsh Sketches, chiefly ecclesiastical, to the...  A., E. S.
# ...

# %%
#acessing each reord in the data 
# loc[]:   eg--> cdt.loc[206] --> acess the 206 indexed record


cdt.loc[480]
# Out:
# Place of Publication                                               London
# Date of Publication                                                  1857
# Publisher                                            Wertheim & Macintosh
# Title                   [The World in which I live, and my place in it...
# Author                                                          A., E. S.
# Contributors                                          BROOME, John Henry.
# Flickr URL              http://www.flickr.com/photos/britishlibrary/ta...
# Name: 480, dtype: object

# %%
cdt.iloc[0]
# Out:
# Place of Publication                                               London
# Date of Publication                                           1879 [1878]
# Publisher                                                S. Tinsley & Co.
# Title                                   Walter Forbes. [A novel.] By A. A
# Author                                                              A. A.
# Contributors                                              FORBES, Walter.
# Flickr URL              http://www.flickr.com/photos/britishlibrary/ta...
# Name: 206, dtype: object

# %%
to_drop
# Out:
# ['Edition Statement',
#  'Corporate Author',
#  'Corporate Contributors',
#  'Corporate Contributors',
#  'Former owner',
#  'Engraver',
#  'Issuance type',
#  'Shelfmarks']

# %%
cdt.head()
# Out:
#                 Place of Publication Date of Publication  \
# Identifier
# 206                           London         1879 [1878]
# 216         London; Virtue & Yorston                1868
# 218                           London                1869
# 472                           London                1851
# 480                           London                1857
#
#                         Publisher  \
# Identifier
# 206              S. Tinsley & Co.
# 216                  Virtue & Co.
# 218         Bradbury, Evans & Co.
# 472                 James Darling
# 480          Wertheim & Macintosh
#
#                                                         Title     Author  \
# Identifier
# 206                         Walter Forbes. [A novel.] By A. A      A. A.
# 216         All for Greed. [A novel. The dedication signed...  A., A. A.
# 218         Love the Avenger. By the author of “All for Gr...  A., A. A.
# 472         Welsh Sketches, chiefly ecclesiastical, to the...  A., E. S.
# ...

# %%
#Clean the specific coloumns and get them a uniform formact to get the better understanding of the dataset enforce consistency

# %%
# use loc function to lock index identifier at 1500 along with date of publication.
cdt.loc[1500:,'Date of Publication'].head()
# Out:
# Identifier
# 1808           1859
# 1905           1888
# 1929    1839, 38-54
# 2836           1897
# 2854           1865
# Name: Date of Publication, dtype: object

# %%
# use of regular expression to extract the first 4 number to use as valid date
extr =cdt['Date of Publication'].str.extract(r'^(\d{4})',expand=False)

# %%
extr.head()
# Out:
# Identifier
# 206    1879
# 216    1868
# 218    1869
# 472    1851
# 480    1857
# Name: Date of Publication, dtype: object

# %%
#dtype used in each coloumns
cdt.dtypes
# Out:
# Place of Publication    object
# Date of Publication     object
# Publisher               object
# Title                   object
# Author                  object
# Contributors            object
# Flickr URL              object
# dtype: object

# %%
# Date of publication coloumns is object dtype. Converting 
cdt['Date of Publication']=pd.to_numeric(extr)

# %%
#checking the weather there is any nullvalue for checking the error to be considered.
cdt['Date of Publication'].isnull()
# Out:
# Identifier
# 206        False
# 216        False
# 218        False
# 472        False
# 480        False
#            ...
# 4158088    False
# 4158128    False
# 4159563     True
# 4159587    False
# 4160339    False
# Name: Date of Publication, Length: 8287, dtype: bool

# %%
cdt['Date of Publication'].isnull().sum()/len(df)
# Out:
# 0.11717147339205986

# %%
cdt.head(10)
# Out:
#                            Place of Publication  Date of Publication  \
# Identifier
# 206                                      London               1879.0
# 216                    London; Virtue & Yorston               1868.0
# 218                                      London               1869.0
# 472                                      London               1851.0
# 480                                      London               1857.0
# 481                                      London               1875.0
# 519                                      London               1872.0
# 667         pp. 40. G. Bryan & Co: Oxford, 1898                  NaN
# 874                                     London]               1676.0
# 1143                                     London               1679.0
#
#                         Publisher  \
# Identifier
# 206              S. Tinsley & Co.
# 216                  Virtue & Co.
# 218         Bradbury, Evans & Co.
# 472                 James Darling
# ...

# %% [markdown]
# Cleaning specific columns

# %%
unwanted_characters = ['[', ',', '-']

def clean_dates(item):
    dop= str(item.loc['Date of Publication'])
    
    if dop == 'nan' or dop[0] == '[':
        return np.NaN
    
    for character in unwanted_characters:
        if character in dop:
            character_index = dop.find(character)
            dop = dop[:character_index]
    
    return dop

df['Date of Publication'] = df.apply(clean_dates, axis = 1)

# %%
df.head()
# Out:
#    Identifier      Place of Publication Date of Publication  \
# 0         206                    London               1879
# 1         216  London; Virtue & Yorston                1868
# 2         218                    London                1869
# 3         472                    London                1851
# 4         480                    London                1857
#
#                Publisher                                              Title  \
# 0       S. Tinsley & Co.                  Walter Forbes. [A novel.] By A. A
# 1           Virtue & Co.  All for Greed. [A novel. The dedication signed...
# 2  Bradbury, Evans & Co.  Love the Avenger. By the author of “All for Gr...
# 3          James Darling  Welsh Sketches, chiefly ecclesiastical, to the...
# 4   Wertheim & Macintosh  [The World in which I live, and my place in it...
#
#       Author                                  Contributors  \
# 0      A. A.                               FORBES, Walter.
# ...

# %%
def clean_title(item):
    title = str(item['Title'])
    
    if title == 'nan':
        return np.NaN
    
    if title[0] == '[':
        title = title[1: title.find(']')]
        
    if 'by' in title:
        title = title[:title.find('by')]
    elif 'By' in title:
        title = title[:title.find('By')]
        
    if '[' in title:
        title = title[:title.find('[')]

    title = title[:-2]
        
    title = list(map(str.capitalize, title.split()))
    return ' '.join(title)
    
df['Title'] = df.apply(clean_title, axis = 1)

# %%
df.head()
# Out:
#    Identifier      Place of Publication Date of Publication  \
# 0         206                    London               1879
# 1         216  London; Virtue & Yorston                1868
# 2         218                    London                1869
# 3         472                    London                1851
# 4         480                    London                1857
#
#                Publisher                                              Title  \
# 0       S. Tinsley & Co.                                      Walter Forbes
# 1           Virtue & Co.                                      All For Greed
# 2  Bradbury, Evans & Co.                                   Love The Avenger
# 3          James Darling  Welsh Sketches, Chiefly Ecclesiastical, To The...
# 4   Wertheim & Macintosh      The World In Which I Live, And My Place In It
#
#       Author                                  Contributors  \
# 0      A. A.                               FORBES, Walter.
# ...

# %% [markdown]
# Cleaning entire dataset

# %%
university_towns = []

with open('/content/BL-Flickr-Images-Book.csv', 'r') as file:
    items = file.readlines()
    states = list(filter(lambda x: '[edit]' in x, items))
    
    for index, state in enumerate(states):
        start = items.index(state) + 1
        if index == 49: #since 50 states
            end = len(items)
        else:
            end = items.index(states[index + 1])
            
        pairs = map(lambda x: [state, x], items[start:end])
        university_towns.extend(pairs)
        
towns_df = pd.DataFrame(university_towns, columns = ['State', 'RegionName'])
towns_df.head()
# Out:
# Empty DataFrame
# Columns: [State, RegionName]
# Index: []

# %%
def clean_up(item):
    if '(' in item:
        return item[:item.find('(') - 1] #since space before '('
    
    if '[' in item:
        return item[:item.find('[')]
    

towns_df =  towns_df.applymap(clean_up)
towns_df.head()
# Out:
# Empty DataFrame
# Columns: [State, RegionName]
# Index: []

# %%
Renaming columns and skipping rows

# %%
olympics_df = pd.read_csv('/content/BL-Flickr-Images-Book.csv', skiprows=1, header=0)
olympics_df.head()
# Out:
#    000000206                     Unnamed: 1                    London  \
# 0        216                            NaN  London; Virtue & Yorston
# 1        218                            NaN                    London
# 2        472                            NaN                    London
# 3        480   A new edition, revised, etc.                    London
# 4        481  Fourth edition, revised, etc.                    London
#
#   1879 [1878]       S. Tinsley & Co.  \
# 0        1868           Virtue & Co.
# 1        1869  Bradbury, Evans & Co.
# 2        1851          James Darling
# 3        1857   Wertheim & Macintosh
# 4        1875      William Macintosh
#
#                    Walter Forbes. [A novel.] By A. A      A. A.  \
# 0  All for Greed. [A novel. The dedication signed...  A., A. A.
# 1  Love the Avenger. By the author of “All for Gr...  A., A. A.
# 2  Welsh Sketches, chiefly ecclesiastical, to the...  A., E. S.
# ...

# %%
new_names = {'Unnamed: 0': 'Country',
           '? Summer': 'Summer Olympics',
           '01 !': 'Gold',
           '02 !': 'Silver',
           '03 !': 'Bronze',
           '? Winter': 'Winter Olympics',
           '01 !.1': 'Gold.1',
           '02 !.1': 'Silver.1',
           '03 !.1': 'Bronze.1',
           '? Games': '# Games', 
           '01 !.2': 'Gold.2',
           '02 !.2': 'Silver.2',
           '03 !.2': 'Bronze.2'}

olympics_df.rename(columns=new_names, inplace=1)
olympics_df.head()
# Out:
#    000000206                     Unnamed: 1                    London  \
# 0        216                            NaN  London; Virtue & Yorston
# 1        218                            NaN                    London
# 2        472                            NaN                    London
# 3        480   A new edition, revised, etc.                    London
# 4        481  Fourth edition, revised, etc.                    London
#
#   1879 [1878]       S. Tinsley & Co.  \
# 0        1868           Virtue & Co.
# 1        1869  Bradbury, Evans & Co.
# 2        1851          James Darling
# 3        1857   Wertheim & Macintosh
# 4        1875      William Macintosh
#
#                    Walter Forbes. [A novel.] By A. A      A. A.  \
# 0  All for Greed. [A novel. The dedication signed...  A., A. A.
# 1  Love the Avenger. By the author of “All for Gr...  A., A. A.
# 2  Welsh Sketches, chiefly ecclesiastical, to the...  A., E. S.
# ...
